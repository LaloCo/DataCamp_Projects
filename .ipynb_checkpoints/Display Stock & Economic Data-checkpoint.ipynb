# %%
# !pip install pandas_datareader

from datetime import date
from pandas_datareader.data import DataReader
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: pandas_datareader in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: pandas>=0.19.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas_datareader) (0.24.1)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas_datareader) (4.3.2)
# Requirement already satisfied: requests>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas_datareader) (2.21.0)
# Requirement already satisfied: wrapt in /Users/eduardorosas/Library/Python/3.7/lib/python/site-packages (from pandas_datareader) (1.10.11)
# Requirement already satisfied: pytz>=2011k in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.19.2->pandas_datareader) (2018.5)
# Requirement already satisfied: numpy>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.19.2->pandas_datareader) (1.16.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.19.2->pandas_datareader) (2.7.5)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2018.10.15)
# Requirement already satisfied: six>=1.5 in /Users/eduardorosas/Library/Python/3.7/lib/python/site-packages (from python-dateutil>=2.5.0->pandas>=0.19.2->pandas_datareader) (1.11.0)

# %% [markdown]
# # Get Facebook stock prices for the last three years

# %%
start = date(2016,3,21)
end = date(2019,3,21)
ticker = 'FB'
data_source = 'iex'

facebook_prices = DataReader(ticker, data_source, start, end)

# %% [markdown]
# # Plot the stock prices

# %%
facebook_prices['close'].plot(title=ticker)
plt.show()

# %% [markdown]
# # Display Economic Data form the Federal Reserve

# %%
start = date(2016,3,21)
# skip end date to obtain the most recent data
series_code = 'DGS10'
data_source = 'fred'

ten_year_treasury_rate = DataReader(series_code, data_source, start)

# %%
ten_year_treasury_rate.plot(title='10 Year Treasory Rate')
plt.show()

# %%
# Get oil prices with DCOILWTICO
start = date(2014,3,21)
# skip end date to obtain the most recent data
series_code = 'DCOILWTICO'
data_source = 'fred'

oil = DataReader(series_code, data_source, start)

# %%
oil.plot(title='10 Year Treasory Rate')
plt.show()

# %% [markdown]
# # Compare Bond and Stock Performance

# %%
start = date(2014,3,21)

series = ['BAMLHYH0A0HYM2TRIV', 'SP500']

data = DataReader(series, 'fred', start)

data.plot(subplots=True, title='Performance Comparison')

plt.show()

# %% [markdown]
# # Display multiple stocks

# %%
tickers = ['AAPL', 'FB', 'AMZN', 'NFLX', 'MSFT']
start = date (2016,3,22)

data = DataReader(tickers, 'iex', start)

print(type(data))
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Index: 755 entries, 2016-03-22 to 2019-03-21
# Data columns (total 25 columns):
# (open, AAPL)      755 non-null float64
# (open, AMZN)      755 non-null float64
# (open, FB)        755 non-null float64
# (open, MSFT)      755 non-null float64
# (open, NFLX)      755 non-null float64
# (high, AAPL)      755 non-null float64
# (high, AMZN)      755 non-null float64
# (high, FB)        755 non-null float64
# (high, MSFT)      755 non-null float64
# (high, NFLX)      755 non-null float64
# (low, AAPL)       755 non-null float64
# (low, AMZN)       755 non-null float64
# (low, FB)         755 non-null float64
# (low, MSFT)       755 non-null float64
# (low, NFLX)       755 non-null float64
# (close, AAPL)     755 non-null float64
# (close, AMZN)     755 non-null float64
# (close, FB)       755 non-null float64
# (close, MSFT)     755 non-null float64
# (close, NFLX)     755 non-null float64
# (volume, AAPL)    755 non-null int64
# (volume, AMZN)    755 non-null int64
# (volume, FB)      755 non-null int64
# (volume, MSFT)    755 non-null int64
# (volume, NFLX)    755 non-null int64
# dtypes: float64(20), int64(5)
# memory usage: 153.4+ KB
# Attributes      open                                       high          \
# Symbols         AAPL    AMZN      FB     MSFT    NFLX      AAPL    AMZN
# date
# 2016-03-22   99.9438  545.11  111.36  50.3154  100.48  101.8810  562.76
# 2016-03-23  101.1118  561.00  112.01  50.7847   99.75  101.6721  572.48
# 2016-03-24  100.1528  567.11  112.13  50.5313   98.64  100.8934  583.55
# 2016-03-28  100.6560  584.40  113.32  50.8785   98.34  100.8365  584.75
# 2016-03-29   99.6020  580.15  113.83  50.3623  101.08  102.3558  595.85
#
# Attributes                             ...     close                           \
# Symbols           FB     MSFT    NFLX  ...      AAPL    AMZN      FB     MSFT
# date                                   ...
# 2016-03-22  112.8800  50.9161  101.52  ...  101.3397  560.48  112.25  50.7471
# 2016-03-23  113.1900  50.9067  100.39  ...  100.7795  569.63  112.54  50.6533
# 2016-03-24  113.0900  50.9912   98.85  ...  100.3427  582.95  113.05  50.8785
# 2016-03-28  114.5889  50.9536  101.44  ...   99.8869  579.87  113.69  50.2497
# 2016-03-29  116.3200  51.4886  104.33  ...  102.2513  593.86  116.14  51.3478
#
# Attributes            volume
# Symbols       NFLX      AAPL     AMZN        FB      MSFT      NFLX
# date
# 2016-03-22   99.84  32444375  4000564  19001076  23124143   9069905
# 2016-03-23   99.59  25703495  3983720  18561974  20129015   8313480
# 2016-03-24   98.36  26132955  5185539  17839119  19949972  10671139
# 2016-03-28  101.21  19411372  3121522  21351751  17025050  12432217
# 2016-03-29  104.13  31190083  4392567  29825340  23924329  16008868
#
# [5 rows x 25 columns]

# %%
close_data = data['close']
close_data.head(10)
# Out:
# Symbols         AAPL    AMZN      FB     MSFT    NFLX
# date
# 2016-03-22  101.3397  560.48  112.25  50.7471   99.84
# 2016-03-23  100.7795  569.63  112.54  50.6533   99.59
# 2016-03-24  100.3427  582.95  113.05  50.8785   98.36
# 2016-03-28   99.8869  579.87  113.69  50.2497  101.21
# 2016-03-29  102.2513  593.86  116.14  51.3478  104.13
# 2016-03-30  104.0366  598.69  114.70  51.6669  102.19
# 2016-03-31  103.4953  593.64  114.10  51.8359  102.23
# 2016-04-01  104.4449  598.50  116.06  52.1550  105.70
# 2016-04-04  105.5179  593.19  112.55  52.0236  104.35
# 2016-04-05  104.2740  586.14  112.22  51.2070  104.94

# %%
close_data.plot(subplots=True)
plt.tight_layout()
plt.show()
